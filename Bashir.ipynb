# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sn



from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
data = pd.read_csv("KNN_Imputation_data.csv")
data
# Out:
#        Unnamed: 0  Unnamed: 0.1        X  comp_bed_9  mat_dep  mat_age  \
# 0               0           1.0      1.0         0.0      3.0     30.0
# 1               1           2.0      2.0         0.0      9.0     26.0
# 2               2           3.0      3.0         0.0      3.0     24.0
# 3               3           4.0      4.0         0.0      5.8     22.0
# 4               4           5.0      5.0         0.0      8.0     31.0
# ...           ...           ...      ...         ...      ...      ...
# 13729       13729       13730.0  13730.0         0.2     13.0     27.0
# 13730       13730       13731.0  13731.0         0.0      6.0     29.0
# 13731       13731       13732.0  13732.0         0.0     21.0     37.0
# 13732       13732       13733.0  13733.0         0.0     10.0     30.0
# 13733       13733       13734.0  13734.0         0.0      6.0     26.0
#
#        weight_16   height_16     iq  comp_noint_bed_16  ...  dep_score  \
# ...

# %%
def linear(data1, data2):
    X_train, X_test, y_train, y_test = train_test_split(data1, data2, test_size=0.2, random_state=48)


    lin_reg = LinearRegression()
    lin_reg.fit(X_train, y_train)

    y_pred = lin_reg.predict(X_test)



    fig, ax = plt.subplots(figsize=(3, 3))
    ax.scatter(X_train, y_train)
    ax.plot(X_test, y_pred, 'r-')
    ax.set_title('{} - {}'.format(i,j))
    ax.set_xlabel(i)
    ax.set_ylabel('{}'.format(j))






array = ["panic_score", "secd_diag", "prim_diag", "has_dep_diag", "dep_thoughts", "dep_score"]
array2 = ["tv_week", "comp_week", "text_week", "tv_wend", "comp_wend", "text_wend"]

for i in array:
    j = "comp_week"
    print(linear(data[[i]], data[[j]]))
# Out:
# None
# None
# None
# None
# None
# None

# %%
def linear(data1, data2):
    X_train, X_test, y_train, y_test = train_test_split(data1, data2, test_size=0.2, random_state=48)


    lin_reg = LinearRegression()
    lin_reg.fit(X_train, y_train)

    y_pred = lin_reg.predict(X_test)


    fig, ax = plt.subplots(figsize=(3, 3))
    ax.scatter(X_train, y_train)
    ax.plot(X_test, y_pred, 'r-')
    ax.set_title('{} - {}'.format(i,j))
    ax.set_xlabel(i)
    ax.set_ylabel('{}'.format(j))


count1 = 0
for i in data:
    j = "dep_thoughts"
    print(linear(data[[i]], data[[j]]))
    count1 += 1
    if count1 >= 20:
        break
# Out:
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None

# %%
#Violin Plots


def violin(xco, yco):
    

    tips = sn.load_dataset("tips")

    ax = sn.violinplot(x=data[xco], y=data[yco], data=tips, fmt = '.3f')
    

print(violin("text_week", "has_dep_diag"))
# Out:
# None

# %%
A = [45,37,42,35,39]
B = [38,31,26,28,33]
C = [10,15,17,21,12]

new = np.array([A,B,C])

covMatrix = np.cov(new,bias=True)
sn.heatmap(covMatrix, annot=True, fmt='g')
plt.show()

# %%
array1 = [i for i in data["panic_score"]]
array2 = [i for i in data["secd_diag"]]
array3 = [i for i in data["prim_diag"]]
array4 = [i for i in data["has_dep_diag"]]
array5 = [i for i in data["dep_thoughts"]]
array6 = [i for i in data["dep_score"]]
array7 = [i for i in data["tv_week"]]
array8 = [i for i in data["comp_week"]]
array9 = [i for i in data["text_week"]]
array10 = [i for i in data["tv_wend"]]
array11 = [i for i in data["comp_wend"]]
array12 = [i for i in data["text_wend"]]



new = np.array([array1, array2, array3, array4, array5, array6, array7, array8, array9, array10, array11, array12])
xlabels = ["panic_score", "secd_diag", "prim_diag", "has_dep_diag", "dep_thoughts", "dep_score", "tv_week", "comp_week", "text_week", "tv_wend", "comp_wend", "text_wend"]

covMatrix = np.cov(new,bias=True)
sn.set(rc = {'figure.figsize':(20,10)})
sn.heatmap(covMatrix, xticklabels = xlabels, yticklabels = xlabels, annot=True, fmt='.3f')
plt.show()
