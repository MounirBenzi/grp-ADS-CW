# %%
# %matplotlib notebook
# !pip install ipympl
# !pip install ipynb
# %matplotlib widget
from ipywidgets import FloatSlider, IntSlider, interact, interact_manual
import numpy as np
import pandas as pd
import seaborn as sns
import math
import matplotlib.pyplot as plt
import prince
import operator
from sklearn.preprocessing import StandardScaler
from sklearn.datasets import load_breast_cancer
from sklearn.decomposition import PCA
df = pd.read_csv("maps-synthetic-data-v1.1.csv")
display(df)
prince.__file__
# Out:
# Requirement already satisfied: ipympl in c:\users\lenovo\anaconda3\lib\site-packages (0.8.8)
# Requirement already satisfied: ipython<9 in c:\users\lenovo\anaconda3\lib\site-packages (from ipympl) (7.22.0)
# Requirement already satisfied: ipywidgets<8,>=7.6.0 in c:\users\lenovo\anaconda3\lib\site-packages (from ipympl) (7.6.3)
# Requirement already satisfied: ipython-genutils in c:\users\lenovo\anaconda3\lib\site-packages (from ipympl) (0.2.0)
# Requirement already satisfied: matplotlib<4,>=2.0.0 in c:\users\lenovo\appdata\roaming\python\python38\site-packages (from ipympl) (3.5.1)
# Requirement already satisfied: pillow in c:\users\lenovo\anaconda3\lib\site-packages (from ipympl) (8.2.0)
# Requirement already satisfied: traitlets<6 in c:\users\lenovo\anaconda3\lib\site-packages (from ipympl) (5.0.5)
# Requirement already satisfied: numpy in c:\users\lenovo\anaconda3\lib\site-packages (from ipympl) (1.20.1)
# Requirement already satisfied: decorator in c:\users\lenovo\anaconda3\lib\site-packages (from ipython<9->ipympl) (5.0.6)
# Requirement already satisfied: pickleshare in c:\users\lenovo\anaconda3\lib\site-packages (from ipython<9->ipympl) (0.7.5)
# Requirement already satisfied: pygments in c:\users\lenovo\anaconda3\lib\site-packages (from ipython<9->ipympl) (2.8.1)
# Requirement already satisfied: backcall in c:\users\lenovo\anaconda3\lib\site-packages (from ipython<9->ipympl) (0.2.0)
# Requirement already satisfied: colorama in c:\users\lenovo\anaconda3\lib\site-packages (from ipython<9->ipympl) (0.4.4)
# Requirement already satisfied: jedi>=0.16 in c:\users\lenovo\anaconda3\lib\site-packages (from ipython<9->ipympl) (0.17.2)
# Requirement already satisfied: setuptools>=18.5 in c:\users\lenovo\anaconda3\lib\site-packages (from ipython<9->ipympl) (52.0.0.post20210125)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\lenovo\anaconda3\lib\site-packages (from ipython<9->ipympl) (3.0.17)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\users\lenovo\anaconda3\lib\site-packages (from ipywidgets<8,>=7.6.0->ipympl) (1.0.0)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\lenovo\anaconda3\lib\site-packages (from ipywidgets<8,>=7.6.0->ipympl) (5.1.3)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\lenovo\anaconda3\lib\site-packages (from ipywidgets<8,>=7.6.0->ipympl) (3.5.1)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\lenovo\anaconda3\lib\site-packages (from ipywidgets<8,>=7.6.0->ipympl) (5.3.4)
# Requirement already satisfied: tornado>=4.2 in c:\users\lenovo\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<8,>=7.6.0->ipympl) (6.1)
# Requirement already satisfied: jupyter-client in c:\users\lenovo\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<8,>=7.6.0->ipympl) (6.1.12)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in c:\users\lenovo\anaconda3\lib\site-packages (from jedi>=0.16->ipython<9->ipympl) (0.7.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\lenovo\anaconda3\lib\site-packages (from matplotlib<4,>=2.0.0->ipympl) (20.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\lenovo\anaconda3\lib\site-packages (from matplotlib<4,>=2.0.0->ipympl) (2.8.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\lenovo\anaconda3\lib\site-packages (from matplotlib<4,>=2.0.0->ipympl) (1.3.1)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\lenovo\anaconda3\lib\site-packages (from matplotlib<4,>=2.0.0->ipympl) (2.4.7)
# Requirement already satisfied: cycler>=0.10 in c:\users\lenovo\anaconda3\lib\site-packages (from matplotlib<4,>=2.0.0->ipympl) (0.10.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\lenovo\anaconda3\lib\site-packages (from matplotlib<4,>=2.0.0->ipympl) (4.32.0)
# Requirement already satisfied: six in c:\users\lenovo\anaconda3\lib\site-packages (from cycler>=0.10->matplotlib<4,>=2.0.0->ipympl) (1.15.0)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in c:\users\lenovo\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets<8,>=7.6.0->ipympl) (3.2.0)
# Requirement already satisfied: jupyter-core in c:\users\lenovo\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets<8,>=7.6.0->ipympl) (4.7.1)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\lenovo\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets<8,>=7.6.0->ipympl) (20.3.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\users\lenovo\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets<8,>=7.6.0->ipympl) (0.17.3)
# Requirement already satisfied: wcwidth in c:\users\lenovo\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython<9->ipympl) (0.2.5)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\lenovo\anaconda3\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets<8,>=7.6.0->ipympl) (6.3.0)
# Requirement already satisfied: pyzmq>=17 in c:\users\lenovo\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.6.0->ipympl) (20.0.0)
# Requirement already satisfied: prometheus-client in c:\users\lenovo\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.6.0->ipympl) (0.10.1)
# Requirement already satisfied: Send2Trash>=1.5.0 in c:\users\lenovo\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.6.0->ipympl) (1.5.0)
# Requirement already satisfied: jinja2 in c:\users\lenovo\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.6.0->ipympl) (2.11.3)
# Requirement already satisfied: argon2-cffi in c:\users\lenovo\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.6.0->ipympl) (20.1.0)
# Requirement already satisfied: nbconvert in c:\users\lenovo\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.6.0->ipympl) (6.0.7)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\lenovo\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.6.0->ipympl) (0.9.4)
# Requirement already satisfied: pywin32>=1.0 in c:\users\lenovo\anaconda3\lib\site-packages (from jupyter-core->nbformat>=4.2.0->ipywidgets<8,>=7.6.0->ipympl) (227)
# Requirement already satisfied: pywinpty>=0.5 in c:\users\lenovo\anaconda3\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.6.0->ipympl) (0.5.7)
# Requirement already satisfied: cffi>=1.0.0 in c:\users\lenovo\anaconda3\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.6.0->ipympl) (1.14.5)
# Requirement already satisfied: pycparser in c:\users\lenovo\anaconda3\lib\site-packages (from cffi>=1.0.0->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.6.0->ipympl) (2.20)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\lenovo\anaconda3\lib\site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.6.0->ipympl) (1.1.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\lenovo\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.6.0->ipympl) (0.8.4)
# Requirement already satisfied: defusedxml in c:\users\lenovo\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.6.0->ipympl) (0.7.1)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\users\lenovo\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.6.0->ipympl) (0.3)
# Requirement already satisfied: testpath in c:\users\lenovo\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.6.0->ipympl) (0.4.4)
# Requirement already satisfied: jupyterlab-pygments in c:\users\lenovo\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.6.0->ipympl) (0.1.2)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\lenovo\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.6.0->ipympl) (0.5.3)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\lenovo\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.6.0->ipympl) (1.4.3)
# Requirement already satisfied: bleach in c:\users\lenovo\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.6.0->ipympl) (3.3.0)
# Requirement already satisfied: nest-asyncio in c:\users\lenovo\anaconda3\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.6.0->ipympl) (1.5.1)
# Requirement already satisfied: async-generator in c:\users\lenovo\anaconda3\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.6.0->ipympl) (1.10)
# Requirement already satisfied: webencodings in c:\users\lenovo\anaconda3\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.6.0->ipympl) (0.5.1)
# Requirement already satisfied: ipynb in c:\users\lenovo\anaconda3\lib\site-packages (0.5.1)
# Warning: Cannot change to a different GUI toolkit: widget. Using notebook instead.
#        Unnamed: 0      X       flag comp_bed_9  mat_dep mat_age  weight_16  \
# 0               1      1  synthetic        NaN      3.0      30  59.294132
# 1               2      2  synthetic        NaN      9.0      26        NaN
# 2               3      3  synthetic        NaN      3.0      24        NaN
# 3               4      4  synthetic         No      NaN      22  49.812426
# 4               5      5  synthetic         No      8.0      31  62.270030
# ...           ...    ...        ...        ...      ...     ...        ...
# 13729       13730  13730  synthetic        NaN     13.0      27        NaN
# 13730       13731  13731  synthetic         No      6.0      29        NaN
# 13731       13732  13732  synthetic        NaN     21.0      37  58.075832
# 13732       13733  13733  synthetic         No     10.0      30        NaN
# 13733       13734  13734  synthetic         No      6.0      26  70.732913
#
#         height_16     iq comp_noint_bed_16  ... dep_score comp_house  \
# 0      181.602831  107.0               NaN  ...       0.0        Yes
# 1             NaN   85.0               NaN  ...       NaN        NaN
# 2             NaN    NaN               NaN  ...       NaN        NaN
# 3      160.224186    NaN               NaN  ...       NaN        NaN
# 4      191.703227  132.0               Yes  ...       NaN        NaN
# ...           ...    ...               ...  ...       ...        ...
# 13729         NaN    NaN               NaN  ...       NaN        NaN
# 13730         NaN    NaN               NaN  ...       NaN        NaN
# 13731  169.235565  108.0               NaN  ...       NaN        NaN
# 13732         NaN  103.0               NaN  ...       0.0        Yes
# 13733  176.873882  102.0               NaN  ...       NaN        NaN
#
#       tv_bed_16   creat_14 comp_games      fam_tv_eve      fam_tv_aft  \
# 0           Yes      often         No  Yes, Some Days           Other
# 1           NaN        NaN        NaN             NaN             NaN
# 2           NaN        NaN        NaN  Yes, Some Days  Yes, Every Day
# 3           NaN        NaN         No             NaN             NaN
# 4           NaN      often         No  Yes, Some Days  Yes, Every Day
# ...         ...        ...        ...             ...             ...
# 13729       NaN        NaN        NaN  Yes, Every Day  Yes, Every Day
# 13730       NaN        NaN         No  Yes, Every Day           Other
# 13731       NaN      often         No           Other           Other
# 13732       NaN  sometimes         No  Yes, Some Days           Other
# 13733       NaN  sometimes        NaN  Yes, Some Days           Other
#
#            fam_tv_mor     sex birth_order
# 0      Yes, Every Day  Female           A
# 1                 NaN  Female           B
# 2               Other    Male           A
# 3                 NaN    Male           A
# 4      Yes, Every Day  Female           A
# ...               ...     ...         ...
# 13729  Yes, Every Day  Female           A
# 13730           Other    Male           A
# 13731           Other    Male           A
# 13732  Yes, Every Day    Male           A
# 13733  Yes, Every Day    Male           A
#
# [13734 rows x 85 columns]
# 'C:\\Users\\Lenovo\\anaconda3\\lib\\site-packages\\prince\\__init__.py'

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-23-38cab14eb0ad> in <module>
# ----> 1 from dython.nominal import associations
#
# ModuleNotFoundError: No module named 'dython'

# %%
import sys 
print(sys.path)
from dython.nominal import associations
# Out:
# ['C:\\Users\\Lenovo\\Documents\\University\\Year3\\grp-ADS-CW', 'C:\\Users\\Lenovo\\anaconda3\\python38.zip', 'C:\\Users\\Lenovo\\anaconda3\\DLLs', 'C:\\Users\\Lenovo\\anaconda3\\lib', 'C:\\Users\\Lenovo\\anaconda3', '', 'C:\\Users\\Lenovo\\anaconda3\\lib\\site-packages', 'C:\\Users\\Lenovo\\anaconda3\\lib\\site-packages\\locket-0.2.1-py3.8.egg', 'C:\\Users\\Lenovo\\anaconda3\\lib\\site-packages\\win32', 'C:\\Users\\Lenovo\\anaconda3\\lib\\site-packages\\win32\\lib', 'C:\\Users\\Lenovo\\anaconda3\\lib\\site-packages\\Pythonwin', 'C:\\Users\\Lenovo\\anaconda3\\lib\\site-packages\\IPython\\extensions', 'C:\\Users\\Lenovo\\.ipython']
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-25-4a74664f4258> in <module>
#       1 import sys
#       2 print(sys.path)
# ----> 3 from dython.nominal import associations
#
# ModuleNotFoundError: No module named 'dython'
