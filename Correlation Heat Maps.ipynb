# %%
import numpy as np
import pandas as pd

from sklearn.decomposition import PCA
from sklearn.manifold import TSNE

import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
data = pd.read_csv("data/clean-data.csv")
data.head()
import seaborn as sns
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\matplotlib\docstring.py:61, in _ArtistKwdocLoader.__missing__(self, key)
#      <a href='file:///c%3A/Users/Mouni/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/matplotlib/docstring.py?line=59'>60</a> try:
# ---> <a href='file:///c%3A/Users/Mouni/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/matplotlib/docstring.py?line=60'>61</a>     cls, = [cls for cls in _recursive_subclasses(Artist)
#      <a href='file:///c%3A/Users/Mouni/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/matplotlib/docstring.py?line=61'>62</a>             if cls.__name__ == name]
#      <a href='file:///c%3A/Users/Mouni/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/matplotlib/docstring.py?line=62'>63</a> except ValueError as e:
#
# ValueError: too many values to unpack (expected 1)
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# c:\Users\Mouni\Documents\Mathematics and Computer Science\grp-ADS-CW\Correlation Heat Maps.ipynb Cell 1' in <cell line: 7>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Mouni/Documents/Mathematics%20and%20Computer%20Science/grp-ADS-CW/Correlation%20Heat%20Maps.ipynb#ch0000000?line=3'>4</a> from sklearn.decomposition import PCA
#       <a href='vscode-notebook-cell:/c%3A/Users/Mouni/Documents/Mathematics%20and%20Computer%20Science/grp-ADS-CW/Correlation%20Heat%20Maps.ipynb#ch0000000?line=4'>5</a> from sklearn.manifold import TSNE
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Mouni/Documents/Mathematics%20and%20Computer%20Science/grp-ADS-CW/Correlation%20Heat%20Maps.ipynb#ch0000000?line=6'>7</a> import matplotlib.pyplot as plt
#       <a href='vscode-notebook-cell:/c%3A/Users/Mouni/Documents/Mathematics%20and%20Computer%20Science/grp-ADS-CW/Correlation%20Heat%20Maps.ipynb#ch0000000?line=7'>8</a> from mpl_toolkits.mplot3d import Axes3D
#       <a href='vscode-notebook-cell:/c%3A/Users/Mouni/Documents/Mathematics%20and%20Computer%20Science/grp-ADS-CW/Correlation%20Heat%20Maps.ipynb#ch0000000?line=8'>9</a> data = pd.read_csv("data/clean-data.csv")
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\matplotlib\pyplot.py:57, in <module>
#      <a href='file:///c%3A/Users/Mouni/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/matplotlib/pyplot.py?line=54'>55</a> from matplotlib import docstring
#      <a href='file:///c%3A/Users/Mouni/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/matplotlib/pyplot.py?line=55'>56</a> from matplotlib.backend_bases import FigureCanvasBase, MouseButton
# ---> <a href='file:///c%3A/Users/Mouni/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/matplotlib/pyplot.py?line=56'>57</a> from matplotlib.figure import Figure, figaspect
#      <a href='file:///c%3A/Users/Mouni/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/matplotlib/pyplot.py?line=57'>58</a> from matplotlib.gridspec import GridSpec, SubplotSpec
#      <a href='file:///c%3A/Users/Mouni/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/matplotlib/pyplot.py?line=58'>59</a> from matplotlib import rcParams, rcParamsDefault, get_backend, rcParamsOrig
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\matplotlib\figure.py:25, in <module>
#      <a href='file:///c%3A/Users/Mouni/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/matplotlib/figure.py?line=21'>22</a> import numpy as np
#      <a href='file:///c%3A/Users/Mouni/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/matplotlib/figure.py?line=23'>24</a> import matplotlib as mpl
# ---> <a href='file:///c%3A/Users/Mouni/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/matplotlib/figure.py?line=24'>25</a> from matplotlib import _blocking_input, docstring, projections
#      <a href='file:///c%3A/Users/Mouni/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/matplotlib/figure.py?line=25'>26</a> from matplotlib.artist import (
#      <a href='file:///c%3A/Users/Mouni/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/matplotlib/figure.py?line=26'>27</a>     Artist, allow_rasterization, _finalize_rasterization)
#      <a href='file:///c%3A/Users/Mouni/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/matplotlib/figure.py?line=27'>28</a> from matplotlib.backend_bases import (
#      <a href='file:///c%3A/Users/Mouni/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/matplotlib/figure.py?line=28'>29</a>     FigureCanvasBase, NonGuiException, MouseButton, _get_renderer)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\matplotlib\projections\__init__.py:58, in <module>
#      <a href='file:///c%3A/Users/Mouni/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/matplotlib/projections/__init__.py?line=55'>56</a> from .geo import AitoffAxes, HammerAxes, LambertAxes, MollweideAxes
#      <a href='file:///c%3A/Users/Mouni/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/matplotlib/projections/__init__.py?line=56'>57</a> from .polar import PolarAxes
# ---> <a href='file:///c%3A/Users/Mouni/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/matplotlib/projections/__init__.py?line=57'>58</a> from mpl_toolkits.mplot3d import Axes3D
#      <a href='file:///c%3A/Users/Mouni/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/matplotlib/projections/__init__.py?line=60'>61</a> class ProjectionRegistry:
#      <a href='file:///c%3A/Users/Mouni/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/matplotlib/projections/__init__.py?line=61'>62</a>     """A mapping of registered projection names to projection classes."""
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\mpl_toolkits\mplot3d\__init__.py:1, in <module>
# ----> <a href='file:///c%3A/Users/Mouni/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/mpl_toolkits/mplot3d/__init__.py?line=0'>1</a> from .axes3d import Axes3D
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\mpl_toolkits\mplot3d\axes3d.py:47, in <module>
#      <a href='file:///c%3A/Users/Mouni/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/mpl_toolkits/mplot3d/axes3d.py?line=39'>40</a> from . import proj3d
#      <a href='file:///c%3A/Users/Mouni/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/mpl_toolkits/mplot3d/axes3d.py?line=40'>41</a> from . import axis3d
#      <a href='file:///c%3A/Users/Mouni/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/mpl_toolkits/mplot3d/axes3d.py?line=43'>44</a> @docstring.interpd
#      <a href='file:///c%3A/Users/Mouni/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/mpl_toolkits/mplot3d/axes3d.py?line=44'>45</a> @cbook._define_aliases({
#      <a href='file:///c%3A/Users/Mouni/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/mpl_toolkits/mplot3d/axes3d.py?line=45'>46</a>     "xlim3d": ["xlim"], "ylim3d": ["ylim"], "zlim3d": ["zlim"]})
# ---> <a href='file:///c%3A/Users/Mouni/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/mpl_toolkits/mplot3d/axes3d.py?line=46'>47</a> class Axes3D(Axes):
#      <a href='file:///c%3A/Users/Mouni/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/mpl_toolkits/mplot3d/axes3d.py?line=47'>48</a>     """
#      <a href='file:///c%3A/Users/Mouni/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/mpl_toolkits/mplot3d/axes3d.py?line=48'>49</a>     3D axes object.
#      <a href='file:///c%3A/Users/Mouni/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/mpl_toolkits/mplot3d/axes3d.py?line=49'>50</a>     """
#      <a href='file:///c%3A/Users/Mouni/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/mpl_toolkits/mplot3d/axes3d.py?line=50'>51</a>     name = '3d'
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\matplotlib\docstring.py:86, in _ArtistPropertiesSubstitution.__call__(self, obj)
#      <a href='file:///c%3A/Users/Mouni/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/matplotlib/docstring.py?line=83'>84</a> super().__call__(obj)
#      <a href='file:///c%3A/Users/Mouni/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/matplotlib/docstring.py?line=84'>85</a> if isinstance(obj, type) and obj.__init__ != object.__init__:
# ---> <a href='file:///c%3A/Users/Mouni/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/matplotlib/docstring.py?line=85'>86</a>     self(obj.__init__)
#      <a href='file:///c%3A/Users/Mouni/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/matplotlib/docstring.py?line=86'>87</a> return obj
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\matplotlib\docstring.py:84, in _ArtistPropertiesSubstitution.__call__(self, obj)
#      <a href='file:///c%3A/Users/Mouni/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/matplotlib/docstring.py?line=82'>83</a> def __call__(self, obj):
# ---> <a href='file:///c%3A/Users/Mouni/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/matplotlib/docstring.py?line=83'>84</a>     super().__call__(obj)
#      <a href='file:///c%3A/Users/Mouni/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/matplotlib/docstring.py?line=84'>85</a>     if isinstance(obj, type) and obj.__init__ != object.__init__:
#      <a href='file:///c%3A/Users/Mouni/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/matplotlib/docstring.py?line=85'>86</a>         self(obj.__init__)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\matplotlib\docstring.py:38, in Substitution.__call__(self, func)
#      <a href='file:///c%3A/Users/Mouni/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/matplotlib/docstring.py?line=35'>36</a> def __call__(self, func):
#      <a href='file:///c%3A/Users/Mouni/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/matplotlib/docstring.py?line=36'>37</a>     if func.__doc__:
# ---> <a href='file:///c%3A/Users/Mouni/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/matplotlib/docstring.py?line=37'>38</a>         func.__doc__ = inspect.cleandoc(func.__doc__) % self.params
#      <a href='file:///c%3A/Users/Mouni/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/matplotlib/docstring.py?line=38'>39</a>     return func
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\matplotlib\docstring.py:64, in _ArtistKwdocLoader.__missing__(self, key)
#      <a href='file:///c%3A/Users/Mouni/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/matplotlib/docstring.py?line=60'>61</a>     cls, = [cls for cls in _recursive_subclasses(Artist)
#      <a href='file:///c%3A/Users/Mouni/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/matplotlib/docstring.py?line=61'>62</a>             if cls.__name__ == name]
#      <a href='file:///c%3A/Users/Mouni/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/matplotlib/docstring.py?line=62'>63</a> except ValueError as e:
# ---> <a href='file:///c%3A/Users/Mouni/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/matplotlib/docstring.py?line=63'>64</a>     raise KeyError(key) from e
#      <a href='file:///c%3A/Users/Mouni/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/matplotlib/docstring.py?line=64'>65</a> return self.setdefault(key, kwdoc(cls))
#
# KeyError: 'Axes3D:kwdoc'

# %%
data = pd.
