# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import seaborn as sns

# %%
df = pd.read_csv("data/clean-data.csv")
df=df.drop(columns=['Unnamed: 0'])
df.head()
# Out:
#    comp_bed_9  mat_dep  mat_age  weight_16   height_16     iq  \
# 0         NaN      3.0     30.0  59.294132  181.602831  107.0
# 1         NaN      9.0     26.0        NaN         NaN   85.0
# 2         NaN      3.0     24.0        NaN         NaN    NaN
# 3         0.0      NaN     22.0  49.812426  160.224186    NaN
# 4         0.0      8.0     31.0  62.270030  191.703227  132.0
#
#    comp_noint_bed_16  comp_int_bed_16  talk_phon_wend  text_wend  ...  \
# 0                NaN              NaN             1.0        0.5  ...
# 1                NaN              NaN             NaN        NaN  ...
# 2                NaN              NaN             NaN        NaN  ...
# 3                NaN              NaN             NaN        NaN  ...
# 4                1.0              NaN             0.0        0.0  ...
#
#    dep_score  comp_house  tv_bed_16  creat_14  comp_games  fam_tv_eve  \
# 0        0.0         1.0        1.0       1.0         0.0         1.0
# ...

# %%
corrMatrix_pearson = tot.corr(method="pearson")
corrMatrix_spearman = tot.corr(method="spearman")
corrMatrix_kendall = tot.corr(method="kendall")

# %%
fig, ax1 = plt.subplots(figsize=(14, 12))
ax1.set_title("Mental Health and Screen Time Features Correlation Matrix - Pearson")
sns.heatmap(corrMatrix_pearson, annot=True, square=True, cmap="crest_r")
plt.show()

# %%
fig, ax2 = plt.subplots(figsize=(14, 12))
ax2.set_title("Mental Health and Screen Time Features Correlation Matrix - Spearman")
sns.heatmap(corrMatrix_spearman, annot=True, square=True, cmap="crest_r")
plt.show()

# %%
fig, ax3 = plt.subplots(figsize=(14, 12))
ax3.set_title("Mental Health and Screen Time Features Correlation Matrix - Kendall")
sns.heatmap(corrMatrix_kendall, annot=True, square=True, cmap="crest_r")
plt.show()
