# %%
import pandas as pd
import numpy as np

untouched_clean= pd.read_csv("data/y")
clean_data_full = pd.read_csv("data/y")
display(clean_data_full)
# Out:
#        Unnamed: 0  dep_score  dep_thoughts  has_dep_diag  prim_diag  secd_diag
# 0               1        0.0           NaN           0.0        0.0        0.0
# 1               2        NaN           NaN           NaN        NaN        NaN
# 2               3        NaN           NaN           NaN        NaN        NaN
# 3               4        NaN           NaN           NaN        NaN        NaN
# 4               5        NaN           NaN           NaN        NaN        NaN
# ...           ...        ...           ...           ...        ...        ...
# 13729       13730        NaN           NaN           NaN        NaN        NaN
# 13730       13731        NaN           NaN           NaN        NaN        NaN
# 13731       13732        NaN           NaN           NaN        NaN        NaN
# 13732       13733        0.0           NaN           0.0        0.0        0.0
# 13733       13734        NaN           NaN           NaN        NaN        NaN
#
# ...

# %%
display(clean_data_full['has_dep_diag'].dropna())
clean_data_full['has_dep_diag'].value_counts()
# untouched_clean['has_dep_diag'].value_counts()
# Out:
# 0        0.0
# 5        0.0
# 7        0.0
# 8        0.0
# 18       0.0
#         ...
# 13720    0.0
# 13721    0.0
# 13722    0.0
# 13725    1.0
# 13732    0.0
# Name: has_dep_diag, Length: 4513, dtype: float64
# 0.0    4124
# 1.0     389
# Name: has_dep_diag, dtype: int64
